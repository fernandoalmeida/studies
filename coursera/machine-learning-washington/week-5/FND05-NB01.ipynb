# %% [markdown]
# # Build a song recommender system

# %%
import turicreate

# %% [markdown]
# # Load some music data

# %%
song_data = turicreate.SFrame('./song_data.sframe/')

# %% [markdown]
# # Explore our data

# %%
song_data
# Out:
# Columns:
# 	user_id	str
# 	song_id	str
# 	listen_count	int
# 	title	str
# 	artist	str
# 	song	str
#
# Rows: 1116609
#
# Data:
# +-------------------------------+--------------------+--------------+
# |            user_id            |      song_id       | listen_count |
# +-------------------------------+--------------------+--------------+
# | b80344d063b5ccb3212f76538f... | SOAKIMP12A8C130995 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBBMDR12A8C13253B |      2       |
# | b80344d063b5ccb3212f76538f... | SOBXHDL12A81C204C0 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBYHAJ12A6701BF1D |      1       |
# | b80344d063b5ccb3212f76538f... | SODACBL12A8C13C273 |      1       |
# | b80344d063b5ccb3212f76538f... | SODDNQT12A6D4F5F7E |      5       |
# | b80344d063b5ccb3212f76538f... | SODXRTY12AB0180F3B |      1       |
# | b80344d063b5ccb3212f76538f... | SOFGUAY12AB017B0A8 |      1       |
# | b80344d063b5ccb3212f76538f... | SOFRQTD12A81C233C0 |      1       |
# ...

# %% [markdown]
# ## Show the most popular songs in the dataset

# %%
song_data['song'].show()
# Out:
# Materializing SArray
# ...

# %% [markdown]
# # Count the number of unique users in the data

# %%
users = song_data['user_id'].unique()

# %%
len(users)
# Out:
# 66346

# %% [markdown]
# # Create a song recommender

# %%
train_data,test_data = song_data.random_split(.8,seed=0)

# %% [markdown]
# ## Create a very simple popularity recommender

# %%
popularity_model = turicreate.popularity_recommender.create(train_data,
                                                           user_id = 'user_id',
                                                           item_id = 'song')
# Out:
# ...
#  To use one of these as a rating column, specify the column name to be used as target
#     and use a method that allows the use of a target.
# Preparing data set.
#     Data has 893580 observations with 66085 users and 9952 items.
#     Data prepared in: 0.50628s
# 893580 observations to process; with 9952 unique items.

# %% [markdown]
# ## Use the popularity model to make some predictions

# %%
popularity_model.recommend(users=[users[0]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+--------+------+
# |            user_id            |              song              | score  | rank |
# +-------------------------------+--------------------------------+--------+------+
# | 279292bb36dbfc7f505e36ebf0... |    Sehr kosmisch - Harmonia    | 4754.0 |  1   |
# | 279292bb36dbfc7f505e36ebf0... |          Undo - Björk          | 4227.0 |  2   |
# | 279292bb36dbfc7f505e36ebf0... | You're The One - Dwight Yoakam | 3781.0 |  3   |
# | 279292bb36dbfc7f505e36ebf0... | Dog Days Are Over (Radio E...  | 3633.0 |  4   |
# | 279292bb36dbfc7f505e36ebf0... |    Revelry - Kings Of Leon     | 3527.0 |  5   |
# | 279292bb36dbfc7f505e36ebf0... | Horn Concerto No. 4 in E f...  | 3161.0 |  6   |
# | 279292bb36dbfc7f505e36ebf0... |     Secrets - OneRepublic      | 3148.0 |  7   |
# ...

# %%
popularity_model.recommend(users=[users[1]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+--------+------+
# |            user_id            |              song              | score  | rank |
# +-------------------------------+--------------------------------+--------+------+
# | c067c22072a17d33310d7223d7... |    Sehr kosmisch - Harmonia    | 4754.0 |  1   |
# | c067c22072a17d33310d7223d7... |          Undo - Björk          | 4227.0 |  2   |
# | c067c22072a17d33310d7223d7... | You're The One - Dwight Yoakam | 3781.0 |  3   |
# | c067c22072a17d33310d7223d7... | Dog Days Are Over (Radio E...  | 3633.0 |  4   |
# | c067c22072a17d33310d7223d7... |    Revelry - Kings Of Leon     | 3527.0 |  5   |
# | c067c22072a17d33310d7223d7... | Horn Concerto No. 4 in E f...  | 3161.0 |  6   |
# | c067c22072a17d33310d7223d7... |     Secrets - OneRepublic      | 3148.0 |  7   |
# ...

# %% [markdown]
# # Build a recommender with personalization

# %%
personalized_model = turicreate.item_similarity_recommender.create(train_data,
                                                                  user_id = 'user_id',
                                                                  item_id = 'song')
# Out:
# ...
#  To use one of these as a rating column, specify the column name to be used as target
#     and use a method that allows the use of a target.
# Preparing data set.
#     Data has 893580 observations with 66085 users and 9952 items.
#     Data prepared in: 0.505172s
# Training model from provided data.
# Gathering per-item and per-user statistics.
# +--------------------------------+------------+
# | Elapsed Time (Item Statistics) | % Complete |
# +--------------------------------+------------+
# | 4.08ms                         | 1.5        |
# | 24.177ms                       | 100        |
# +--------------------------------+------------+
# Setting up lookup tables.
# Processing data in one pass using dense lookup tables.
# +-------------------------------------+------------------+-----------------+
# | Elapsed Time (Constructing Lookups) | Total % Complete | Items Processed |
# +-------------------------------------+------------------+-----------------+
# ...

# %% [markdown]
# ## Apply personalized model to make song recommendations

# %%
personalized_model.recommend(users=[users[0]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+
# |            user_id            |              song              |
# +-------------------------------+--------------------------------+
# | 279292bb36dbfc7f505e36ebf0... | Riot In Cell Block Number ...  |
# | 279292bb36dbfc7f505e36ebf0... | Sei Lá Mangueira - Elizeth...  |
# | 279292bb36dbfc7f505e36ebf0... |      The Stallion - Ween       |
# | 279292bb36dbfc7f505e36ebf0... |        Rain - Subhumans        |
# | 279292bb36dbfc7f505e36ebf0... | West One (Shine On Me) - T...  |
# | 279292bb36dbfc7f505e36ebf0... | Back Against The Wall - Ca...  |
# | 279292bb36dbfc7f505e36ebf0... | Life Less Frightening - Ri...  |
# | 279292bb36dbfc7f505e36ebf0... | A Beggar On A Beach Of Gol...  |
# | 279292bb36dbfc7f505e36ebf0... | Audience Of One - Rise Against |
# | 279292bb36dbfc7f505e36ebf0... | Blame It On The Boogie - T...  |
# ...

# %%
personalized_model.recommend(users=[users[1]])
# Out:
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+-------------------------------+
# |            user_id            |              song             |
# +-------------------------------+-------------------------------+
# | c067c22072a17d33310d7223d7... | Grind With Me (Explicit Ve... |
# | c067c22072a17d33310d7223d7... |   There Goes My Baby - Usher  |
# | c067c22072a17d33310d7223d7... | Panty Droppa [Intro] (Albu... |
# | c067c22072a17d33310d7223d7... | Nobody (Featuring Athena C... |
# | c067c22072a17d33310d7223d7... | Youth Against Fascism - So... |
# | c067c22072a17d33310d7223d7... |      Nice & Slow - Usher      |
# | c067c22072a17d33310d7223d7... | Making Love (Into The Nigh... |
# | c067c22072a17d33310d7223d7... |    Naked - Marques Houston    |
# | c067c22072a17d33310d7223d7... | I.nner Indulgence - DESTRU... |
# | c067c22072a17d33310d7223d7... | Love Lost (Album Version) ... |
# ...

# %% [markdown]
# # Apply model to find similar songs in the data set

# %%
personalized_model.get_similar_items(['With Or Without You - U2'])
# Out:
# Columns:
# 	song	str
# 	similar	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +--------------------------+-------------------------------+
# |           song           |            similar            |
# +--------------------------+-------------------------------+
# | With Or Without You - U2 | I Still Haven't Found What... |
# | With Or Without You - U2 | Hold Me_ Thrill Me_ Kiss M... |
# | With Or Without You - U2 |    Window In The Skies - U2   |
# | With Or Without You - U2 |          Vertigo - U2         |
# | With Or Without You - U2 |   Sunday Bloody Sunday - U2   |
# | With Or Without You - U2 |            Bad - U2           |
# | With Or Without You - U2 |     A Day Without Me - U2     |
# | With Or Without You - U2 | Another Time Another Place... |
# | With Or Without You - U2 |          Walk On - U2         |
# | With Or Without You - U2 |     Get On Your Boots - U2    |
# +--------------------------+-------------------------------+
# ...

# %%
personalized_model.get_similar_items(['Chan Chan (Live) - Buena Vista Social Club'])
# Out:
# Columns:
# 	song	str
# 	similar	str
# 	score	float
# 	rank	int
#
# Rows: 10
#
# Data:
# +-------------------------------+--------------------------------+
# |              song             |            similar             |
# +-------------------------------+--------------------------------+
# | Chan Chan (Live) - Buena V... | Murmullo - Buena Vista Soc...  |
# | Chan Chan (Live) - Buena V... | La Bayamesa - Buena Vista ...  |
# | Chan Chan (Live) - Buena V... | Amor de Loca Juventud - Bu...  |
# | Chan Chan (Live) - Buena V... |   Diferente - Gotan Project    |
# | Chan Chan (Live) - Buena V... |       Mistica - Orishas        |
# | Chan Chan (Live) - Buena V... | Hotel California - Gipsy Kings |
# | Chan Chan (Live) - Buena V... |     Nací Orishas - Orishas     |
# | Chan Chan (Live) - Buena V... |    Le Moulin - Yann Tiersen    |
# | Chan Chan (Live) - Buena V... |     Gitana - Willie Colon      |
# | Chan Chan (Live) - Buena V... |    Criminal - Gotan Project    |
# ...

# %% [markdown]
# # Compare the models quantitatively
# We now formally compare the popularity and the personalized models using precision-recall curves.

# %%
model_performance = turicreate.recommender.util.compare_models(test_data, [popularity_model, personalized_model], user_sample=.05)
# Out:
# compare_models: using 2931 users to estimate model performance
# PROGRESS: Evaluate model M0
# recommendations finished on 1000/2931 queries. users per second: 29475.9
# recommendations finished on 2000/2931 queries. users per second: 30361.5
# WARNING:root:Model trained without a target. Skipping RMSE computation.
# Precision and recall summary statistics by cutoff
# +--------+----------------------+----------------------+
# | cutoff |    mean_precision    |     mean_recall      |
# +--------+----------------------+----------------------+
# |   1    | 0.01944728761514843  | 0.004807272412185416 |
# |   2    | 0.019106107130672137 | 0.009458309611840824 |
# |   3    | 0.019561014443307222 | 0.015583023822532528 |
# |   4    | 0.018850221767314924 | 0.02001107141844094  |
# |   5    | 0.017604912998976454 | 0.023397697681218674 |
# |   6    | 0.017741385192766957 | 0.028139297868059413 |
# |   7    | 0.01681532387775994  | 0.03116862003760677  |
# ...

# %% [markdown]
# The table shows that the personalized model provides much better performance.

# %% [markdown]
# ## Quiz

# %%
len(song_data[song_data['artist'] == 'Kanye West']['user_id'].unique())
# Out:
# 2522

# %%
len(song_data[song_data['artist'] == 'Foo Fighters']['user_id'].unique())
# Out:
# 2055

# %%
len(song_data[song_data['artist'] == 'Taylor Swift']['user_id'].unique())
# Out:
# 3246

# %%
len(song_data[song_data['artist'] == 'Lady GaGa']['user_id'].unique())
# Out:
# 2928

# %% [markdown]
# ### Most and least popular songs

# %%
songs_popularity = song_data.groupby(key_column_names='artist', operations={'total_count': turicreate.aggregate.SUM('listen_count')})

# %%
songs_popularity.sort('total_count', ascending=False)
# Out:
# Columns:
# 	artist	str
# 	total_count	int
#
# Rows: 3375
#
# Data:
# +------------------------+-------------+
# |         artist         | total_count |
# +------------------------+-------------+
# |     Kings Of Leon      |    43218    |
# |     Dwight Yoakam      |    40619    |
# |         Björk          |    38889    |
# |        Coldplay        |    35362    |
# | Florence + The Machine |    33387    |
# |     Justin Bieber      |    29715    |
# |    Alliance Ethnik     |    26689    |
# |      OneRepublic       |    25754    |
# |         Train          |    25402    |
# |     The Black Keys     |    22184    |
# +------------------------+-------------+
# [3375 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
songs_popularity.sort('total_count', ascending=True)
# Out:
# Columns:
# 	artist	str
# 	total_count	int
#
# Rows: 3375
#
# Data:
# +-------------------------------+-------------+
# |             artist            | total_count |
# +-------------------------------+-------------+
# |        William Tabbert        |      14     |
# |         Reel Feelings         |      24     |
# | Beyoncé feat. Bun B and Sl... |      26     |
# |             Diplo             |      30     |
# |         Boggle Karaoke        |      30     |
# |         harvey summers        |      31     |
# |             Nâdiya            |      36     |
# | Kanye West / Talib Kweli /... |      38     |
# |          Jody Bernal          |      38     |
# |        Aneta Langerova        |      38     |
# +-------------------------------+-------------+
# [3375 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ### Most recommended songs

# %%
subset_test_users = test_data['user_id'].unique()[0:10000]

# %%
personalized_model.recommend(subset_test_users,k=1)
# Out:
# recommendations finished on 1000/10000 queries. users per second: 26771.6
# recommendations finished on 2000/10000 queries. users per second: 31710.8
# recommendations finished on 3000/10000 queries. users per second: 35667.6
# recommendations finished on 4000/10000 queries. users per second: 39079.3
# recommendations finished on 5000/10000 queries. users per second: 39970.9
# recommendations finished on 6000/10000 queries. users per second: 40531
# recommendations finished on 7000/10000 queries. users per second: 41308.4
# recommendations finished on 8000/10000 queries. users per second: 41684.3
# recommendations finished on 9000/10000 queries. users per second: 41835.6
# recommendations finished on 10000/10000 queries. users per second: 39370.2
# Columns:
# 	user_id	str
# 	song	str
# 	score	float
# 	rank	int
#
# Rows: 10000
#
# Data:
# +-------------------------------+-------------------------------+
# |            user_id            |              song             |
# ...

# %%
song_data.groupby(key_column_names='song', operations={'count': turicreate.aggregate.COUNT()}).sort('count', ascending=False)
# Out:
# Columns:
# 	song	str
# 	count	int
#
# Rows: 9952
#
# Data:
# +--------------------------------+-------+
# |              song              | count |
# +--------------------------------+-------+
# |    Sehr kosmisch - Harmonia    |  5970 |
# |          Undo - Björk          |  5281 |
# | You're The One - Dwight Yoakam |  4806 |
# | Dog Days Are Over (Radio E...  |  4536 |
# |    Revelry - Kings Of Leon     |  4339 |
# | Horn Concerto No. 4 in E f...  |  3949 |
# |     Secrets - OneRepublic      |  3916 |
# |       Tive Sim - Cartola       |  3185 |
# | Fireflies - Charttraxx Karaoke |  3171 |
# |    Hey_ Soul Sister - Train    |  3132 |
# +--------------------------------+-------+
# [9952 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.
